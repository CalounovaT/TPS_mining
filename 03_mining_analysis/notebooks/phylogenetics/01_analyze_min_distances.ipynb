# %%
import pandas as pd

# %%
df = pd.read_csv('min_distances.csv', index_col=0)

# %%
df
# Out:
#              Unnamed: 0  distance_to_closest_characterized  \
# 0        uniprot_131927                           5.041915
# 1        uniprot_250979                           4.527023
# 2     mgnify_new_191805                           4.245652
# 3        uniprot_059474                           8.548534
# 4        uniprot_235390                           5.579579
# ...                 ...                                ...
# 2124         tsa_014046                           9.838331
# 2125  mgnify_new_156167                           5.459766
# 2126  mgnify_new_158943                           5.421982
# 2127  mgnify_new_208088                           5.442459
# 2128     uniprot_217631                           4.603259
#
#      closest_characterized_leaf
# 0                        B3TPQ7
# 1                        B3TPQ7
# 2                        B3TPQ7
# 3                        B3TPQ7
# 4                        B3TPQ7
# ...                         ...
# ...

# %%
df['closest_characterized_leaf'].nunique()
# Out:
# 555

# %%
df['closest_characterized_leaf'].value_counts()
# Out:
# closest_characterized_leaf
# B3TPQ7        8546
# J7LH11        1492
# D5KXJ0        1172
# Q84LB2         992
# D5SJ87         559
#               ...
# KUL85185.1       1
# P37271           1
# B6UV92           1
# A0A2Z6AQX6       1
# B4XAK5           1
# Name: count, Length: 555, dtype: int64

# %%
df['distance_to_closest_characterized'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.sort_values(by='distance_to_closest_characterized', ascending=False).head(50)
# Out:
#              Unnamed: 0  distance_to_closest_characterized  \
# 1775         bfd_031549                          13.008800
# 1178     uniprot_075539                          12.529165
# 1526         bfd_072972                          12.250691
# 6            bfd_130884                          12.164498
# 568          bfd_018016                          12.084795
# 1344         tsa_041786                          12.061268
# 133   mgnify_new_045930                          12.043865
# 693   mgnify_new_053248                          12.031452
# 1257     uniprot_046816                          12.021596
# 665          tsa_035838                          11.908709
# 793          tsa_030661                          11.898712
# 164          tsa_036876                          11.860738
# 1256     uniprot_056012                          11.782959
# 694          bfd_161490                          11.769068
# 1093     uniprot_138064                          11.727598
# ...
